# %% [markdown]
# # Project Status Check

# %%
from pathlib import Path

required = [
    'data/raw/Visium_Human_Breast_Cancer_filtered_feature_bc_matrix.h5',
    'data/raw/spatial/tissue_hires_image.png'
]
for p in required:
    path = Path(p)
    print(f'{p}:', 'FOUND' if path.exists() else 'MISSING')
