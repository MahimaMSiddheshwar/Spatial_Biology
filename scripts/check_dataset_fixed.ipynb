# %% [markdown]
# # Dataset Status (Simple)

# %%
from pathlib import Path

matrix = Path('data/raw/Visium_Human_Breast_Cancer_filtered_feature_bc_matrix.h5')
spatial = Path('data/raw/Visium_Human_Breast_Cancer_spatial.tar.gz')

print('Expression Matrix:', 'FOUND' if matrix.exists() else 'MISSING')
print('Spatial Archive:', 'FOUND' if spatial.exists() else 'MISSING')
if matrix.exists() and spatial.exists():
    print('Dataset complete and ready')
